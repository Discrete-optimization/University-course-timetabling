# %% [markdown]
# ## Distribution of classes on weekdays
#
# Classes are held on different days of the week. Note that the possibility of taking classes on Thursdays and Fridays is less than other days.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
week_days = ['Saturday', 'Sunday', 'Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday']
probabilities = [0.195, 0.19, 0.19, 0.19, 0.19, 0.04, 0.005]

# %% [markdown]
# ### np.random.choice()
# The NumPy random choice() function accepts four parameters. The mandatory parameter is the list or array of elements or numbers. When we pass the list of elements to the NumPy random choice() function, it randomly selects the single element and returns it as a one-dimensional array, but if we specify some size to the size parameter, then it returns the one-dimensional array of that specified size.

# %%
arr = np.random.choice(week_days, size=500, p=probabilities)

# %% [markdown]
# ### print arr

# %%
counts = []
for wd in week_days:
    rep = len(arr[arr == wd])
    counts.append(rep)
    print("number of {} is : {}".format(wd, rep))
    
print(counts)
# Out:
# number of Saturday is : 89
# number of Sunday is : 106
# number of Monday is : 92
# number of Tuesday is : 101
# number of Wednesday is : 90
# number of Thursday is : 21
# number of Friday is : 1
# [89, 106, 92, 101, 90, 21, 1]

# %% [markdown]
# ### plot results

# %%
fig, ax = plt.subplots()
bar_labels = week_days

c = []
for counter in counts:
    darkness = ((counter) / 200) + 0.1
    curr_c = (0.2, 0.6, 0.3, 1-darkness)
    c.append(curr_c)
            
ax.bar(week_days, counts, label=bar_labels, color=c)
plt.xticks(rotation=90)
ax.set_facecolor("Black")
ax.set_ylabel('ٔNumer of classes')
ax.set_title('Distribution of classes on weekdays')

plt.show()

fig, ax = plt.subplots()
ax.set_title('Distribution of classes on weekdays')
ax.pie(counts, labels=bar_labels)
plt.show()
